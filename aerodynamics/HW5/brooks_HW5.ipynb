# %% [markdown]
# ### Slade Brooks
# ### brooksl@mail.uc.edu
# ### 03.10.23
# # Aero Assignment 5

# %% [markdown]
# # Part 1

# %% [markdown]
# ## L/D
# ![image.png](attachment:image.png)

# %% [markdown]
# ## $C_{L}$
# ![image.png](attachment:image.png)

# %% [markdown]
# ## $C_{D}$
# ![image.png](attachment:image.png)

# %% [markdown]
# ## $C_{M}$
# ![image.png](attachment:image.png)
