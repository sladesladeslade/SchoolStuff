# %% [markdown]
# ### Slade Brooks
# ### brooksl@mail.uc.edu
# ### 03.10.23
# # Aero Assignment 5

# %% [markdown]
# # Part 1

# %% [markdown]
# ## L/D
# ![image.png](attachment:image.png)

# %% [markdown]
# ## $C_{L}$
# ![image.png](attachment:image.png)

# %% [markdown]
# ## $C_{D}$
# ![image.png](attachment:image.png)

# %% [markdown]
# ## $C_{M}$
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Explanation

# %% [markdown]
# The sim became unsteady at +10 degrees and -6 degrees aoa. I reran the -6 and -8 to try and improve the shape of the curve.

# %% [markdown]
# I ran + aoas starting at 10 degrees until 16 where the wing stalled (CL dropped) in increments of 2deg.

# %% [markdown]
# The unsteady cases either converged to a single solution or the values were averaged after the resiudals showed a consistent oscillation.

# %% [markdown]
# # Part 2

# %% [markdown]
# ## TAFT Results

# %% [markdown]
# We can see below that the TAFT matches the slope of the majority of the lift and moment coefficient very well. However, when approaching stall or unsteadiness the TAFT approximation does not hold.

# %% [markdown]
# ### $C_{L}$
# ![image.png](attachment:image.png)

# %% [markdown]
# ### $C_{M}$
# ![image.png](attachment:image.png)
