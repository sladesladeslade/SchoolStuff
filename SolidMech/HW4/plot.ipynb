# %%
import matplotlib.pyplot as plt
import matplotlib
import math
import numpy as np

# %%
epsilon1x = -.4794
y=0
epsilon2x = .1345
epsilon3x = .6449

plt.plot(epsilon3x, y, "o", markersize=10,label="Epsilon 1")
plt.plot(epsilon2x, y, "o", markersize=10,label="Epsilon 2")
plt.plot(epsilon1x, y, "o", markersize=10,label="Epsilon 3")

theta = np.linspace(0, 360, 10000)

mohr1x = .56215*np.cos(theta) + .08275
mohr1y = .56215*np.sin(theta)
plt.scatter(mohr1x,mohr1y,color="black",s=0.5)
mohr2x = .2552*np.cos(theta) + .3897
mohr2y = .2552*np.sin(theta)
plt.scatter(mohr2x,mohr2y,color="black",s=0.5)
mohr3x = .30695*np.cos(theta) - .17245
mohr3y = .30695*np.sin(theta)
plt.scatter(mohr3x,mohr3y,color="black",s=0.5)

plt.axis("scaled")
plt.xlabel("Epsilon N (MPa)")
plt.ylabel("1/2 Gamma N (MPa)")
plt.title("Mohr's Strain Circles")
plt.legend(loc="upper left")
plt.annotate("(0.6449, 0)",xy=(0.6449,0),xytext=(.66, .045))
plt.annotate("(0.1345, 0)",xy=(0.1345,0),xytext=(.16, .045))
plt.annotate("(-0.4794, 0)",xy=(-0.4794,0),xytext=(-.45, .045))
plt.show()
