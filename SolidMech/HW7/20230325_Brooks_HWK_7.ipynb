# %% [markdown]
# # AEEM 3062
# # HOMEWORK # 7
# # 2022-2023 SPRING
# ### Name: Slade Brooks
# ### M#: 13801712
# ### DUE: 11.59 PM on 2/25/2023

# %% [markdown]
# ## Problem 1
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Part A
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Part B
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Part C
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Part D
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 2
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ### Part A
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Part B
# ![image.png](attachment:image.png)
