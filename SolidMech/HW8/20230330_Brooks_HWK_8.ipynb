# %% [markdown]
# # AEEM 3062
# # HOMEWORK # 8
# # 2022-2023 SPRING
# ### Name: Slade Brooks
# ### M#: 13801712
# ### DUE: 11.59 PM on 3/30/2023

# %% [markdown]
# ## Problem 1
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)
# ![image.png](attachment:image-3.png)

# %% [markdown]
# ### Part A
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Section 1:
# $$
# \frac{\partial N_1}{\partial x_1} = 0, \ N_1 = C_1 \\
# \frac{\partial V_1}{\partial x_1} = q, \ V_1 = qx + C_2 \\
# \frac{\partial M_1}{\partial x_1} = V_1 = qx + C_2, \ M_1 = \frac{1}{2}qx^2 + C_2x + C_3a \\
# \frac{\partial u_1}{\partial x_1} = \frac{N_1}{E \Sigma} = \frac{C_1}{E \Sigma}, \ u_1 = \frac{1}{E \Sigma}(C_1x + C_4a) \\
# \frac{\partial \varphi_1}{\partial x_1} = \frac{M_1}{EI} = \frac{\frac{1}{2}qx^2 + C_2x + C_3a}{EI}, \\ \varphi_1 = \frac{1}{EI}(\frac{1}{6}qx^3 + \frac{1}{2}C_2x^2 + C_3ax + C_5a^2) \\
# \frac{\partial w_1}{\partial x_1} = \varphi_1 = \frac{1}{EI}(\frac{1}{6}qx^3 + \frac{1}{2}C_2x^2 + C_3ax + C_5a^2), \\ w_1= \frac{1}{EI}(\frac{1}{24}qx^4 + \frac{1}{6}C_2x^3 + \frac{1}{2}C_3ax^2 + C_5a^2x + C_6a^3)
# $$

# %% [markdown]
# Section 2:
# $$
# \frac{\partial N_2}{\partial x_1} = 0, \ N_2 = C_7 \\
# \frac{\partial V_2}{\partial x_1} = q, \ V_2 = qx + C_8 \\
# \frac{\partial M_2}{\partial x_1} = V_2 = qx + C_8, \ M_2 = \frac{1}{2}qx^2 + C_8x + C_9b \\
# \frac{\partial u_2}{\partial x_1} = \frac{N_2}{E \Sigma} = \frac{C_7}{E \Sigma}, \ u_2 = \frac{1}{E \Sigma}(C_7x + C_{10}b) \\
# \frac{\partial \varphi_2}{\partial x_1} = \frac{M_2}{EI} = \frac{\frac{1}{2}qx^2 + C_8x + C_9b}{EI}, \\ \varphi_2 = \frac{1}{EI}(\frac{1}{6}qx^3 + \frac{1}{2}C_8x^2 + C_9bx + C_{11}b^2) \\
# \frac{\partial w_2}{\partial x_1} = \varphi_2 = \frac{1}{EI}(\frac{1}{6}qx^3 + \frac{1}{2}C_8x^2 + C_9bx + C_{11}b^2), \\ w_2= \frac{1}{EI}(\frac{1}{24}qx^4 + \frac{1}{6}C_8x^3 + \frac{1}{2}C_9bx^2 + C_{11}b^2x + C_{12}b^3)
# $$

# %% [markdown]
# Section 3:
# $$
# \frac{\partial N_3}{\partial x_3} = 0,\ N_3 = C_{13} \\
# \frac{\partial V_3}{\partial x_3} = 0,\ V_3 = C_{14} \\
# \frac{\partial M_3}{\partial x_3} = V_3 = C_{14},\ M_3 = C_{14}x + C_{15}L_3\\
# \frac{\partial u_3}{\partial x_3} = \frac{N_3}{E'\Sigma'} = \frac{C_{13}}{E'\Sigma'},\ u_3 = \frac{1}{E'\Sigma'}(C_{13}x + C_{16}L_3)\\
# \frac{\partial \varphi_3}{\partial x_3} = \frac{M_3}{E'I'} = \frac{C_{14}x + C_{15}L_3}{E'I'},\\ \varphi_3 = \frac{1}{E'I'}(\frac{1}{2}C_{14}x^2 + C_{15}L_3x + C_{17}L_3^2)\\
# \frac{\partial w_3}{\partial x_3} = \varphi_3 = \frac{1}{E'I'}(\frac{1}{2}C_{14}x^2 + C_{15}L_3x + C_{17}L_3^2),\\ w_3 = \frac{1}{E'I'}(\frac{1}{6}C_{14}x^3 + \frac{1}{2}C_{15}L_3x + C_{17}L_3^2x + C_{18}L_3^3)
# $$

# %% [markdown]
# Define boundary conditions for the external ends:
# $$
# u_1(0) = 0 \\
# w_1(0) = 0 \\
# \varphi_1(0) = 0 \\
# N_2(L) = 0 \\
# V_2(L) = 0 \\
# M_2(L) = 0 \\
# M_3(0) = 0 \\
# u_3(0) = 0 \\
# w_3(0) = 0 \\
# $$

# %% [markdown]
# Define boundary conditions @ pin B:
# $$
# u_1(a) = u_2(a) \\
# w_1(a) = w_2(a) \\
# u_1(a)\cos(\theta) + w_1(a)\sin(\theta) - u_3(L_3) = 0 \\
# u_1(a)\sin(\theta) + w_1(a)\cos(\theta) - w_3(L_3) = 0 \\
# \varphi_1(a) = \varphi_2(a) \\
# N_2(a)\cos(\theta) - N_1(a)\cos(\theta) - N_3(L_3) + V_1(a)\sin(\theta) - V_2(a)\sin(\theta) = 0 \\
# -N_2(a)\sin(\theta) + N_1(a)\sin(\theta) + V_3(L_3) + V_1(a)\cos(\theta) - V_2(a)\cos(\theta) = 0 \\
# M_1(a) = M_2(a) \\
# M_3(L_3) = 0
# $$

# %% [markdown]
# Plug in and solve:

# %% [markdown]
# $$
# u_1(0) = 0 = \frac{1}{E \Sigma}(C_10 + C_4a),\ C_4a = 0,\\ C_4 = 0
# $$

# %% [markdown]
# $$
# w_1(0) = 0 = \frac{1}{EI}(\frac{1}{24}q0^4 + \frac{1}{6}C_20^3 + \frac{1}{2}C_3a0^2 + C_5a^20 + C_6a^3),\ C_6a^3 = 0,\\ C_6 = 0
# $$

# %% [markdown]
# $$
# \varphi_1(0) = 0 = \frac{1}{EI}(\frac{1}{6}q0^3 + \frac{1}{2}C_20^2 + C_3a0 + C_5a^2),\ C_5a^2=0,\\ C_5 = 0
# $$

# %% [markdown]
# $$
# N_2(L) = 0 = C_7,\\ C_7 = 0
# $$

# %% [markdown]
# $$
# V_2(L) = 0 = qL + C_8,\\ C_8 = -qL
# $$

# %% [markdown]
# $$
# M_2(L) = 0 = \frac{1}{2}qL^2 -qL^2 + C_9b,\\ C_9 = \frac{qL^2}{2b}
# $$

# %% [markdown]
# $$
# M_3(0) = 0 = C_{14}0 + C_{15}L_3,\ C_{15}L_3 = 0,\\ C_{15} = 0
# $$

# %% [markdown]
# $$
# u_3(0) = 0 = \frac{1}{E'\Sigma'}(C_{13}0 + C_{16}L_3),\ C_{16}L_3 = 0,\\ C_{16} = 0
# $$

# %% [markdown]
# $$
# w_3(0) = 0 = \frac{1}{E'I'}(\frac{1}{6}C_{14}0^3 + \frac{1}{2}C_{15}L_30 + C_{17}L_3^20 + C_{18}L_3^3),\ C_{18}L_3^3 = 0,\\ C_{18} = 0
# $$

# %% [markdown]
# $$
# u_1(a) = u_2(a),\ \frac{1}{E \Sigma}(C_1a + 0a) = \frac{1}{E \Sigma}(0a + C_{10}b),\ C_1a = C_{10}b,\\ (a)C_1 - (b)C_{10} = 0
# $$

# %% [markdown]
# $$
# w_1(a) = w_2(a),\ \frac{1}{EI}(\frac{1}{24}qa^4 + \frac{1}{6}C_2a^3 + \frac{1}{2}C_3a^3 + 0a^3 + 0a^3) = \\\frac{1}{EI}(\frac{1}{24}qa^4 + \frac{1}{6}C_8a^3 + \frac{1}{2}C_9ba^2 + C_{11}b^2a + C_{12}b^3), \\
# (\frac{a^3}{6})C_2 + (\frac{a^3}{2})C_3 - (\frac{a^3}{6})C_8 - (\frac{ba^2}{2})C_9 - (b^2a)C_{11} - (b^3)C_{12} = 0
# $$

# %% [markdown]
# $$
# u_1(a)\cos(\theta) + w_1(a)\sin(\theta) - u_3(L_3) = 0,\\ (\frac{1}{E \Sigma}(C_1a + 0a))\cos(\theta) + (\frac{1}{EI}(\frac{1}{24}qa^4 + \frac{1}{6}C_2a^3 + \frac{1}{2}C_3a^3 + 0a^2x + 0a^3))\sin(\theta) \\- \frac{1}{E'\Sigma'}(C_{13}L_3 + 0L_3), \\
# (\frac{a\cos(\theta)}{E\Sigma})C_1 + (\frac{a^3\sin(\theta)}{6EI})C_2 + (\frac{a^3\sin(\theta)}{2EI})C_3 - (\frac{L_3}{E'\Sigma'})C_{13} = -\frac{qa^4\sin(\theta)}{24EI}
# $$

# %% [markdown]
# $$
# u_1(a)\sin(\theta) + w_1(a)\cos(\theta) - w_3(L_3) = 0,\\
# (\frac{1}{E \Sigma}(C_1a + 0a))\sin(\theta) + (\frac{1}{EI}(\frac{1}{24}qa^4 + \frac{1}{6}C_2a^3 + \frac{1}{2}C_3a^3 + 0a^2x + 0a^3))\cos(\theta) \\
# - \frac{1}{E'I'}(\frac{1}{6}0x^3 + \frac{1}{2}0L_3x + C_{17}L_3^3 + 0L_3^3) = 0, \\
# (\frac{a\sin(\theta)}{E\Sigma})C_1 + (\frac{a^3\cos(\theta)}{6EI})C_2 + (\frac{a^3\cos(\theta)}{2EI})C_3 - (\frac{L_3^3}{E'I'})C_{17} = -\frac{qa^4\cos(\theta)}{24EI}
# $$

# %% [markdown]
# $$
# \varphi_1(a) = \varphi_2(a),\ \frac{1}{EI}(\frac{1}{6}qa^3 + \frac{1}{2}C_2a^2 + C_3a^2 + 0a^2) = \\ \frac{1}{EI}(\frac{1}{6}qa^3 + \frac{1}{2}C_8a^2 + C_9ba + C_{11}b^2), \\
# (\frac{a^2}{2})C_2 + (a^2)C_3 - (\frac{a^2}{2})C_8 - (ba)C_9 - (b^2)C_{11} = 0
# $$

# %% [markdown]
# $$
# N_2(a)\cos(\theta) - N_1(a)\cos(\theta) - N_3(L_3) + V_1(a)\sin(\theta) - V_2(a)\sin(\theta) = 0,\\
# 0\cos(\theta) - C_1\cos(\theta) - C_{13} + (qa+C_2)\sin(\theta) - (qa+C_8)\sin(\theta) = 0, \\
# -(\cos(\theta))C_1 + (\sin(\theta))C_2 - (\sin(\theta))C_8 - C_{13} = 0
# $$

# %% [markdown]
# $$
# -N_2(a)\sin(\theta) + N_1(a)\sin(\theta) + V_3(L_3) + V_1(a)\cos(\theta) - V_2(a)\cos(\theta) = 0,\\
# -0\sin(\theta) + C_1\sin(\theta) + 0 + (qa+C_2)\cos(\theta) - (qa+C_8)\cos(\theta) = 0,\\
# (\sin(\theta))C_1 + (\cos(\theta))C_2 - (\cos(\theta))C_8 = 0
# $$

# %% [markdown]
# $$
# M_1(a) = M_2(a),\ \frac{1}{2}qa^2 + C_2a + C_3a = \frac{1}{2}qx^2 + C_8a + C_9b, \\
# (a)C_2 + (a)C_3 - (a)C_8 - (b)C_9 = 0
# $$

# %% [markdown]
# $$
# M_3(L_3) = 0,\ C_{14}L_3 + 0L_3 =0,\ C_{14}L_3=0,\\ C_{14} = 0
# $$

# %% [markdown]
# Now create a matrix:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Part B
# ![image.png](attachment:image.png)

# %% [markdown]
# First we can calulate all of the values (and convert everything to m and Pa):
# $$
# \theta = \tan^{-1}{(\frac{H}{a})} = 42.71^{\circ} = 0.7454 \text{rad}\\
# L_3 = \sqrt{H^2+a^2} = 1.769\text{m} \\
# \Sigma = hw - (h-2t)(w-2t) = 6.24E-4 \text{m$^2$} \\
# \Sigma' = \pi(\frac{D}{2})^2 - \pi(\frac{d}{2})^2 = 6.786E-4\text{m$^2$} \\
# I = \frac{bh^3-b_1h_1^3}{12} = 5.235E-7 \text{m$^4$} \\
# I' = \frac{\pi(D^4-d^4)}{64} = 4.405E-7 \text{m$^4$}
# $$

# %% [markdown]
# Then plug in to the matrix in Matlab and solve for the coefficients:

# %% [markdown]
# $$
# C_1 = -55731.1 \\
# C_2 = 2344.2 \\
# C_3 = -836.4971 \\
# C_4 = 0 \\
# C_5 = 0 \\
# C_6 = 0 \\
# C_7 = 0 \\
# C_8 = -2800 \\
# C_9 = 2074.1 \\
# C_{10} = -2683.3 \\
# C_{11} = -596.2744 \\
# C_{12} = 95.6984 \\
# C_{13} = 7584.3 \\
# C_{14} = 0 \\
# C_{15} = 0 \\
# C_{16} = 0 \\
# C_{17} = 1.807 \\
# C_{18} = 0
# $$

# %% [markdown]
# Then I programmed the equations with their coefficients into matlab to get the plots (I am not showing all of that here because i programmed the equations from above into matlab and used the constants directly from the matrix that solved for them):

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
