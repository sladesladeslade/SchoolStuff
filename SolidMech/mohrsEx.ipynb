# %%
from mohrs import mohrsCirc
import matplotlib.pyplot as plt

# %%
mohrsCirc(-120.834, -6.6697, 53.5037, "stress")
plt.annotate("(23.417, 30.0867)",xy=(23.417, 30.0867),xytext=(25, 34))
plt.show()
