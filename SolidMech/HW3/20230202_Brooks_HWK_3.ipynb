# %% [markdown]
# # AEEM 3062
# # HOMEWORK # 3
# # 2022-2023 SPRING
# ### Name: Slade Brooks
# ### M#: 13801712
# ### DUE: 11.59 PM on 2/2/2023

# %% [markdown]
# ## Problem 1
# ![image.png](attachment:image.png)

# %% [markdown]
# The stress matrices are given by:
# $\quad\sigma_{n} = \begin{bmatrix} \frac{P}{wh} & 0 & 0 \\ 0 & 0 & 0 \\ 0 & 0 & 0 \end{bmatrix}
# $

# %% [markdown]
# From the notes:
# $$
# \sigma_{n}=t*n=\begin{bmatrix} n_{x} & n_{y} & n_{z} \end{bmatrix}*\begin{bmatrix} \sigma_{xx} & \tau_{xy} & \tau_{xz} \\  & \sigma_{yy} & \tau_{yz} \\ sim &  & \sigma_{zz} \end{bmatrix}*\begin{bmatrix} n_{x} \\ n_{y} \\ n_{z} \end{bmatrix}
# $$

# %% [markdown]
# $$
# \tau_{n}= t-(t*n)n =  \begin{bmatrix} \sigma_{xx} & \tau_{xy} & \tau_{xz} \\  & \sigma_{yy} & \tau_{yz} \\ sim &  & \sigma_{zz} \end{bmatrix} * \begin{bmatrix} n_{x} \\ n_{y} \\ n_{z} \end{bmatrix} - \sigma_{n}*\begin{bmatrix} n_{x} \\ n_{y} \\ n_{z} \end{bmatrix}
# $$

# %% [markdown]
# $n$ can never act in the y direction so $n_{y}$ is 0 $\\$
# $ n_{x}$ and $n_{z}$ are based on $\theta$, with $n_{x}=\cos{\theta}$ and $n_{z}=\sin{\theta}\\$
# ![image.png](attachment:image.png)

# %% [markdown]
# Substituting $n$ and $\hat\sigma$ into $\sigma_{n}$ gives:
# $ \quad\sigma_{n}=\begin{bmatrix} \cos{\theta} & 0 & \sin{\theta} \end{bmatrix}*\begin{bmatrix} \frac{P}{wh} & 0 & 0 \\ 0 & 0 & 0 \\ 0 & 0 & 0 \end{bmatrix}*\begin{bmatrix} \cos{\theta} \\ 0 \\ \sin{\theta} \end{bmatrix}
# $

# %% [markdown]
# Multiply the first two matrices using matlab.

# %% [markdown]
# $$
# \sigma_{n}= \begin{bmatrix} \frac{P}{wh}\cos{\theta} & 0 & 0 \end{bmatrix}*\begin{bmatrix} \cos{\theta} \\ 0 \\ \sin{\theta} \end{bmatrix}
# $$

# %% [markdown]
# Multiply the remaining two matrices using matlab.

# %% [markdown]
# $$
# \fbox{$\sigma_{n}=\frac{P\cos^{2}{\theta}}{wh}$}
# $$

# %% [markdown]
# Do the same for $\tau_{n}$ giving:
# $
# \quad\tau_{n}= t-(t*n)n =  \begin{bmatrix} \frac{P}{wh} & 0 & 0 \\ 0 & 0 & 0 \\ 0 & 0 & 0 \end{bmatrix} * \begin{bmatrix} \cos{\theta} \\ 0 \\ \sin{\theta} \end{bmatrix} - \frac{P\cos^{2}{\theta}}{wh}*\begin{bmatrix} \cos{\theta} \\ 0 \\ \sin{\theta} \end{bmatrix}
# $

# %% [markdown]
# $$
# \tau_{n}=\begin{bmatrix} \frac{P\cos{\theta}}{wh} \\0\\0 \end{bmatrix} - \begin{bmatrix} \frac{P\cos^{3}{\theta}}{wh} \\ 0 \\ \frac{P\cos^{2}{\theta}\sin{\theta}}{wh} \end{bmatrix}
# $$

# %% [markdown]
# $$
# \fbox{$\tau_{n}=\begin{bmatrix} \frac{P\cos{\theta} - P\cos^{3}{\theta}}{wh} \\ 0 \\ \frac{-P\cos^{2}{\theta}\sin{\theta}}{wh} \end{bmatrix}$}
# $$

# %% [markdown]
# $\tau_{n}$ at each angle equals the length of the vector $\tau_{n}$ to be found using Matlab's norm() function.

# %% [markdown]
# The two functions $\sigma_{n}$ and $\tau_{n}$ are plotted using Matlab's plot() function.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This shows that $tau_{n}$ has maximums at angles: $$\fbox{$\theta=45^{\circ},135^{\circ},225^{\circ},315^{\circ}$}$$

# %% [markdown]
# ## Problem 2
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Part A
# ![image.png](attachment:image.png)

# %% [markdown]
# The locations of the values of the Mohr's circles $\sigma_{1},\sigma_{2},$ and $\sigma_{3}$ are the eigenvalues of the stress tensor $\sigma$.

# %% [markdown]
# Using Matlab's eig() function we can get the eigenvalues of $\sigma$.

# %% [markdown]
# $$
# \begin{bmatrix} \sigma_{1} & 0 & 0 \\ 0 & \sigma_{2} & 0 \\ 0 & 0 & \sigma_{3} \end{bmatrix} =
# \fbox{$\begin{bmatrix} -120.834 & 0 & 0 \\ 0 & -6.6697 & 0 \\ 0 & 0 & 53.5037 \end{bmatrix}$}
# $$

# %% [markdown]
# Then we plot these points on a graph. The largest point becomes $\sigma_{1}$, the next largest is $\sigma_{2}$, and so on. Then, the Mohr's circles are plotted. This is done by plotting one circle with a diameter from $\sigma_{1}$ to $\sigma_{3}$, one from $\sigma_{1}$ to $\sigma_{2}$, and one from $\sigma_{2}$ to $\sigma_{3}$.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Part B
# ![image.png](attachment:image.png)
