# %% [markdown]
# ### Slade Brooks
# ### M13801712
# ### brooksl@mail.uc.edu

# %% [markdown]
# # AEEM 3013 Exam 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 1. Projectile and Shock

# %% [markdown]
# ### Given

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# Given the diagram above with $V_p$ varying from 900 to 1450 ft/s, plot $V_s$ and $T_g$ versus $V_p$ and explain the trends.

# %% [markdown]
# ### Assumptions

# %% [markdown]
# - steady, uniform flow
# - isentropic everywhere except shock
# - air is CPG with $\gamma=1.4$, $R=53.35$ $\text{ft lbf}/\text{lb} ^\circ \text{R}$

# %% [markdown]
# ### Analysis

# %% [markdown]
# First do a coordinate transformation to analyze with a stationary shock (so regular shock relation equations apply):

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# $T_1 = T_i = 50^\circ \text{F} = 509.67^\circ \text{R}$

# %% [markdown]
# $P_1 = P_i = 1.15 \text{atm}$

# %% [markdown]
# We can use the equation for $V_s$ that is derived from static shock relation equations:
# $$
# V_s = \frac{\gamma+1}{4}V_g+\frac{1}{2}\sqrt{(\frac{\gamma+1}{2})^2V_g^2+4\gamma RT_1}
# $$

# %% [markdown]
# We must convert R to usable units:
# $$
# R = \frac{53.35\text{ft lbf}}{\text{lbm $^\circ$R}}*\frac{32.2 \text{ft lbm}}{\text{lbf s$^2$}} = 1717.87 \frac{\text{ft $^2$}}{\text{s $^2$ $^\circ$R}}
# $$

# %% [markdown]
# $$
# \fbox{$V_s = \frac{\gamma+1}{4}V_g+\frac{1}{2}\sqrt{(\frac{\gamma+1}{2})^2V_g^2+6871.5\gamma T_1}$}
# $$

# %% [markdown]
# We will need to calculate $M_1$ and $M_2$:
# $$
# M_1 = \frac{V_1}{\sqrt{\gamma RT_1}} = \frac{V_1}{\sqrt{1717.87\gamma T_1}}
# $$

# %% [markdown]
# $$
# M_2 = \sqrt{\frac{M_1^2+\frac{2}{\gamma-1}}{\frac{2\gamma}{\gamma-1}M_1^2 - 1}}
# $$

# %% [markdown]
# We know that $T_2 = T_g$, so we can use regular shock relation equations to find $T_2/T_g$:
# $$
# \fbox{$T_g = T_2 = T_1 \frac{(1+\frac{\gamma-1}{2}M_1^2)}{(1+\frac{\gamma-1}{2}M_2^2)}$}
# $$

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# $$
# \text{Figure 1. Plot of shock speed as projectile speed varies between 900 and 1450 ft/s}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# \text{Figure 2. Plot of static temperature after the shock as projectile speed varies between 900 and 1450 ft/s}
# $$

# %% [markdown]
# ### Results

# %% [markdown]
# ### Discussion

# %% [markdown]
# ## Problem 2. Shock in Channel

# %% [markdown]
# ### Given

# %% [markdown]
# ### Assumptions

# %% [markdown]
# ### Analysis

# %% [markdown]
# ### Results

# %% [markdown]
# ### Discussion

# %% [markdown]
# ## Problem 3. C-D Nozzle Design

# %% [markdown]
# ### Given

# %% [markdown]
# ### Assumptions

# %% [markdown]
# ### Analysis

# %% [markdown]
# ### Results

# %% [markdown]
# ### Discussion
